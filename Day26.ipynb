# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\Admin\Desktop\Saurabh\weather_data_cities.xlsx")

# %%
df
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york         32.0        6.0    Rain
# 1  2017-01-02  new york         36.0        7.0   Sunny
# 2  2017-01-03  new york         28.0       12.0    Snow
# 3  2017-01-04  new york         33.0        7.0   Sunny
# 4  2017-01-01    mumbai         90.0        5.0   Sunny
# 5  2017-01-02    mumbai         85.0       12.0     Fog
# 6  2017-01-03    mumbai         87.0       15.0     Fog
# 7  2017-01-04    mumbai         92.0        5.0    Rain
# 8  2017-01-01     paris         45.0       20.0   Sunny
# 9  2017-01-02     paris         50.0       13.0  Cloudy
# 10 2017-01-03     paris         54.0        8.0  Cloudy
# 11 2017-01-04     paris         42.0       10.0  Cloudy

# %%
df["city"]
# Out:
# 0     new york
# 1     new york
# 2     new york
# 3     new york
# 4       mumbai
# 5       mumbai
# 6       mumbai
# 7       mumbai
# 8        paris
# 9        paris
# 10       paris
# 11       paris
# Name: city, dtype: object

# %%
df.temperature.mean()
# Out:
# 56.166666666666664

# %%
df.temperature.sum()
# Out:
# 674.0

# %%
df.temperature.std()
# Out:
# 25.04480832912131

# %%
df.describe().round()
# Out:
#        temperature  windspeed
# count         12.0       12.0
# mean          56.0       10.0
# std           25.0        5.0
# min           28.0        5.0
# 25%           35.0        7.0
# 50%           48.0        9.0
# 75%           86.0       12.0
# max           92.0       20.0

# %%
df1=pd.read_csv(r"C:\Users\Admin\Desktop\Saurabh\Euro_2012_stats_TEAM.csv")

# %%
df1
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
euro12=df1

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
euro12.Team.value_counts().sum()
# Out:
# 16

# %%
euro12.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
euro12.head()
# Out:
#    Unnamed: 0            Team  Goals  Shots on target  Shots off target  \
# 0           0         Croatia      4               13                12
# 1           1  Czech Republic      4               13                18
# 2           2         Denmark      4               10                10
# 3           3         England      5               11                18
# 4           4          France      3               22                24
#
#   Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0             51.9%            16.0%                          32
# 1             41.9%            12.9%                          39
# 2             50.0%            20.0%                          27
# 3             50.0%            17.2%                          40
# 4             37.9%             6.5%                          65
#
#    Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# ...

# %%
euro12.shape[1]
# Out:
# 36

# %%
discipline=euro12[["Team","Red Cards","Yellow Cards"]]

# %%
euro12.Team==euro12["Red Cards"]=>1
# Out:
#   Input In [20]
#     euro12.Team==euro12["Red Cards"]=>1
#     ^
# SyntaxError: cannot assign to comparison

# %%
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending = True)
# Out:
#                    Team  Red Cards  Yellow Cards
# 2               Denmark          0             4
# 5               Germany          0             4
# 3               England          0             5
# 8           Netherlands          0             5
# 15              Ukraine          0             5
# 4                France          0             6
# 12               Russia          0             6
# 1        Czech Republic          0             7
# 14               Sweden          0             7
# 0               Croatia          0             9
# 13                Spain          0            11
# 10             Portugal          0            12
# 7                 Italy          0            16
# 11  Republic of Ireland          1             6
# 9                Poland          1             7
# 6                Greece          1             9

# %%
discipline["Yellow Cards"].mean()
# Out:
# 7.4375

# %%
euro12.head()
# Out:
#    Unnamed: 0            Team  Goals  Shots on target  Shots off target  \
# 0           0         Croatia      4               13                12
# 1           1  Czech Republic      4               13                18
# 2           2         Denmark      4               10                10
# 3           3         England      5               11                18
# 4           4          France      3               22                24
#
#   Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0             51.9%            16.0%                          32
# 1             41.9%            12.9%                          39
# 2             50.0%            20.0%                          27
# 3             50.0%            17.2%                          40
# 4             37.9%             6.5%                          65
#
#    Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# ...

# %%
euro12[euro12.Goals>6]
# Out:
#     Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 5            5  Germany     10               32                32
# 13          13    Spain     12               42                33
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5              47.8%            15.6%                          80
# 13             55.9%            16.0%                         100
#
#     Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5              2              1  ...          10                 62.6%
# 13             0              1  ...          15                 93.8%
#
#     Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 5          63              49       12             4          0       15
# 13        102              83       19            11          0       17
#
#     Subs off  Players Used
# 5         15            17
# 13        17            18
#
# [2 rows x 36 columns]

# %%
euro12[euro12.Team.str.startswith("G")]
# Out:
#    Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 5           5  Germany     10               32                32
# 6           6   Greece      5                8                18
#
#   Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5             47.8%            15.6%                          80
# 6             30.7%            19.2%                          32
#
#    Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5             2              1  ...          10                 62.6%
# 6             1              1  ...          13                 65.1%
#
#    Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 5         63              49       12             4          0       15
# 6         67              48       12             9          1       12
#
#    Subs off  Players Used
# 5        15            17
# 6        12            20
#
# [2 rows x 36 columns]

# %%
first_7_column  = euro12.iloc[:  :7]
first_7_column
# Out:
#     Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 0            0  Croatia      4               13                12
# 7            7    Italy      6               34                45
# 14          14   Sweden      5               17                19
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 7              43.0%             7.5%                         110
# 14             47.2%            13.8%                          39
#
#     Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 0              0              0  ...          13                 81.3%
# 7              2              0  ...          20                 74.1%
# 14             3              0  ...           8                 61.6%
#
#     Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# ...

# %%
first_7_column
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
last3column=euro12.iloc[: :-3]

# %%
last3column
# Out:
#     Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 15          15  Ukraine      2                7                26
# 12          12   Russia      5                9                31
# 9            9   Poland      2               15                23
# 6            6   Greece      5                8                18
# 3            3  England      5               11                18
# 0            0  Croatia      4               13                12
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 15             21.2%             6.0%                          38
# 12             22.5%            12.5%                          59
# 9              39.4%             5.2%                          48
# 6              30.7%            19.2%                          32
# 3              50.0%            17.2%                          40
# 0              51.9%            16.0%                          32
#
# ...

# %%
euro12.loc[euro12.Team.isin(["England","Italy","Russia"]),["Team","Shooting Accuracy"]]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
